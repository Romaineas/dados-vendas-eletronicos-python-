# %% [markdown]
# # trabalho sobre gráficos estatísticos
#
# **Análises de histogramas e bloxpot**
#
# base teste de 22986 rows × 9 columns
#
# treinamento com o curso de Wallison Silva

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('/content/Base Vendas.xlsx - Planilha1.csv')

# %%
df.head()
# Out:
#       SKU  Tamanho Pedido            Loja Data da Venda  Código Cliente  \
# 0  HL1018               5    Porto Alegre      1/1/2016              64
# 1  HL1001               2       Fortaleza      1/1/2016             796
# 2  HL1008               1  Rio de Janeiro      1/1/2016             374
# 3  HL1021               1          Recife      1/1/2016             165
# 4  HL1008               5        Salvador      1/1/2016             712
#
#    Preço Unitário      Faturamento     Marca     Categoria
# 0   R$  1.200,00     R$  6.000,00     Xiaomi   Smart Watch
# 1   R$  2.600,00     R$  5.200,00         LG     Televisão
# 2   R$  2.000,00     R$  2.000,00     Philco     Televisão
# 3   R$  3.000,00     R$  3.000,00    Samsung       Celular
# 4   R$  2.000,00    R$  10.000,00     Philco     Televisão

# %%
df.isnull()
# Out:
#          SKU  Tamanho Pedido   Loja  Data da Venda  Código Cliente  \
# 0      False           False  False          False           False
# 1      False           False  False          False           False
# 2      False           False  False          False           False
# 3      False           False  False          False           False
# 4      False           False  False          False           False
# ...      ...             ...    ...            ...             ...
# 22981  False           False  False          False           False
# 22982  False           False  False          False           False
# 22983  False           False  False          False           False
# 22984  False           False  False          False           False
# 22985  False           False  False          False           False
#
#         Preço Unitário   Faturamento   Marca   Categoria
# 0                False         False   False       False
# ...

# %%
df.describe()
# Out:
#        Tamanho Pedido  Código Cliente
# count    22986.000000    22986.000000
# mean         3.004481      400.641956
# std          1.413052      236.708073
# min          1.000000        1.000000
# 25%          2.000000      196.000000
# 50%          3.000000      394.000000
# 75%          4.000000      603.000000
# max          5.000000      822.000000

# %% [markdown]
# **1º quartil 25% - compraram  2.0 produtos
#
# 2º quartil 50% = compraram até 3.0 produtos
#
# 3º quartil 75% - compraram até 4.0 produtos**

# %%
#estatistica descritiva
df['Tamanho Pedido'].describe()
# Out:
# count    22986.000000
# mean         3.004481
# std          1.413052
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: Tamanho Pedido, dtype: float64

# %%
px.box(df, x='Tamanho Pedido')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(df, x='Tamanho Pedido', points='all')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **HISTOGRAMA 2D - HEATMAP**

# %%
px.density_heatmap(df, x =' Marca', y=' Faturamento', histfunc='avg')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
